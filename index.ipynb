# %% [markdown]
# # Recommendation Systems - Lab
#
# ## Introduction
#
# Now that you've gotten an introduction to collaborative filtering and recommendation systems, it's time to put your skills to test and attempt to build a recommendation system for a real world dataset! For this exercise, you'll be using a dataset regarding the book reviews on the Amazon marketplace. While the previous lesson focused on user-based recommendation systems, you'll apply a parallel process for an item-based recommendation system to recommend similar books at the bottom of the product page.
#
# ## Objectives
#
# You will be able to:
# * Implement a recommendation system on a real world dataset

# %% [markdown]
# ## Load the Dataset

# %%
#Your code here
import pandas as pd
df = pd.read_csv('books_data.edgelist', names=['source', 'target', 'weight'], delimiter=' ')
df.head()
# Out:
#        source      target  weight
# 0  0827229534  0804215715     0.7
# 1  0827229534  156101074X     0.5
# 2  0827229534  0687023955     0.8
# 3  0827229534  0687074231     0.8
# 4  0827229534  082721619X     0.7

# %% [markdown]
# ## Load the MetaData

# %%
#Your code here
meta = pd.read_csv('books_meta.txt', sep='\t')
meta.head()
# Out:
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  SalesRank  \
# 0  clergi sermon subject religion preach spiritu ...  Book     396585
# 1  subject witchcraft earth religion spiritu base...  Book     168596
# 2       general hobbi subject craft home garden book  Book    1270652
# 3  spiritu translat commentari christian book gui...  Book     631289
# 4  subject religion spiritu busi christian live w...  Book     455160
#
#    TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 0             2        5.0                 8             0.80
# 1            12        4.5                 9             0.85
# 2             1        5.0                 0             0.00
# 3             1        4.0                 6             0.79
# 4             0        0.0                 4             1.00

# %% [markdown]
# ## Select Books to Test Your Recommender On
#
# Select a small subset of books that you are interested in generating recommendations for.

# %%
import networkx as nx
G = nx.Graph()

# %%
#Your code here
GOT = meta[meta.Title.str.contains('Plants')]
GOT
# Out:
#             Id        ASIN                                              Title  \
# 837       1180  0609800434  Eighty Great Natural Shade Garden Plants (Ken ...
# 1668      2344  8798685414                          Aquarium Plants Catalogue
# 1988      2787  0849315751   Trace Elements in Soil and Plants, Third Edition
# 2187      3067  0817304428  Poisonous Plants and Venomous Animals of Alaba...
# 3210      4486  0893273996  Illustrated Companion to Gleason and Cronquist...
# 3738      5249  0811730859  The Illustrated Book of Wildflowers and Shrubs...
# 4408      6168  0813016282          Landscape Plants for Subtropical Climates
# 5557      7818  1560987294  The Origin and Early Diversification of Land P...
# 7377     10499  1585420344  Cleansing the Doors of Perception: The Religio...
# 8607     12250  0805038612  Easy Care Native Plants : A Guide to Selecting...
# 9141     13077  0300057903  Tobacco and Shamanism in South America (Psycho...
# 9954     14280  1552094200             Topiary and the Art of Training Plants
# 10290    14730  0811720764               Field Guide to Medicinal Wild Plants
# 11184    15945  0815511922  Odor and Corrosion Control in Sanitary Sewerag...
# 11665    16606  087563723X  Herbaceous Perennial Plants: A Treatise on The...
# 12987    18444  0870714902                    Handbook of Northwestern Plants
# 15120    21463  0520215419  Plants of the Tahoe Basin: Flowering Plants, T...
# 2187               0        0.0                 0             0.00
# 3210               1        5.0                 0             0.00
# 3738               3        4.5                 6             0.86
# 4408               3        3.5                 4             0.00
# 5557               2        2.0                 4             0.90
# 7377              13        4.5                 4             1.00
# 8607               5        4.0                 4             0.77
# 9141               2        3.0                 0             0.00
# 9954               2        4.5                 4             0.90
# 10290              3        4.0                 3             0.58
# 11184              0        0.0                 0             0.00
# 11665              4        5.0                 7             0.71
# 12987              0        0.0                 1             0.00
# 15120              4        5.0                 2             0.00
# 15946              0        0.0                 6             0.71
# 15982              0        0.0                 3             0.58
# 16052              0        0.0                 0             0.00
# 16215              2        4.5                 2             1.00
# 16442              0        0.0                 0             0.00
# 16673              0        0.0                 0             0.00
# 17539              0        0.0                 3             1.00
# 18721              4        4.5                 3             0.58
# 19240              0        0.0                 2             0.00
# 19910              6        5.0                10             0.43
# 20014              7        2.0                 3             1.00
# 20312              0        0.0                 0             0.00
# 20774              0        0.0                 5             0.83
# ...              ...        ...               ...              ...
# 369391             3        5.0                 4             0.60
# 369571             1        4.0                 5             0.81
# 370304             2        5.0                 6             0.84
# 370343             3        4.5                 0             0.00
# 370468             0        0.0                 0             0.00
# 370740             0        0.0                 6             0.86
# 370875             4        5.0                 8             0.78
# 371054             5        5.0                 3             0.83
# 371217             0        0.0                 0             0.00
# 371269             2        5.0                 4             0.87
# 371631             5        3.5                 0             0.00
# 371899             0        0.0                 3             0.00
# 374387             3        4.5                 5             0.80
# 374569             8        5.0                42             0.65
# 376122             1        4.0                 2             0.00
# 376793            33        5.0                 5             0.84
# 378093             1        4.0                 0             0.00
# 380684             3        3.5                13             0.62
# 381572             1        5.0                 6             0.71
# 381618             2        4.0                 7             0.79
# 381701             4        4.5                 5             0.48
# 382305             2        4.5                 1             0.00
# 384615            28        4.0                15             0.59
# 385123             1        5.0                 0             0.00
# 386523            14        4.0                13             0.69
# 386767             1        5.0                 0             0.00
# 387935             1        4.0                 0             0.00
# 388792             1        5.0                 0             0.00
# 392092             2        5.0                 4             1.00
# 392728             3        4.5                 4             0.43
#
# [562 rows x 10 columns]

# %% [markdown]
# ## Generate Recommendations for a Few Books of Choice
#
# The 'books_data.edgelist' has conveniently already calculated the distance between items for you. Given this preprocessed and data, it's time to employ collaborative filtering to generate recommendations! Generate the top 10 recommendations for each book in the subset you chose. Be sure to print the book name that you are generating recommendations for as well as the name of the books being recommended.

# %%
#Your code here
rec_dict = {}
id_name_dict = dict(zip(meta.ASIN, meta.Title))
for row in GOT.index:
    book_id = GOT.ASIN[row]
    book_name = id_name_dict[book_id]
    most_similar = df[(df.source==book_id)
                      | (df.target==book_id)
                     ].sort_values(by='weight', ascending=False).head(10)
    most_similar['source_name'] = most_similar['source'].map(id_name_dict)
    most_similar['target_name'] = most_similar['target'].map(id_name_dict)
    recommendations = []
    for row in most_similar.index:
        if most_similar.source[row] == book_id:
            recommendations.append((most_similar.target_name[row], most_similar.weight[row]))
        else:
            recommendations.append((most_similar.source_name[row], most_similar.weight[row]))
    rec_dict[book_name] = recommendations
    print("Recommendations for:", book_name)
    for r in recommendations:
        print(r)
    print('\n\n')

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you effectively created a recommendation system for a real world dataset!
